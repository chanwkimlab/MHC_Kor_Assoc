# %% [markdown]
# jupyter nbconvert 7_1_gcta_bivar.ipynb --to script
#
#
# python 7_1_gcta_bivar.py $WINDOW
#
# for i in {00..101};do python 6_gcta_uni.py $i;done
#
# for i in {00..10};do python 4_association.py $i;done
#
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6292650/

# %%
import os
import sys

import logging
import re
import pathlib

import datetime

import numpy as np
import pandas as pd
from scipy.stats import pearsonr

import matplotlib.pyplot as plt

import seaborn as sns

from pyplink import PyPlink

from basic_tools import *

# %%
log = logging.getLogger('logger')
log.setLevel(logging.DEBUG)

log_file_name=datetime.datetime.now().strftime('%Y%m%d_%H%M%S')+'.log'
log_file_path=data_out_gcta_path+log_file_name
fileHandler = logging.FileHandler(log_file_path)
streamHandler = logging.StreamHandler()

formatter = logging.Formatter(' %(asctime)s [%(levelname)s] %(lineno)d > %(message)s')
fileHandler.setFormatter(formatter)
streamHandler.setFormatter(formatter)

log.addHandler(fileHandler)
log.addHandler(streamHandler)

# %%
plink_KCHIP_HLA_AA_SNP_1000G=PyPlink(plink_KCHIP_HLA_AA_SNP_1000G_path)
plink_KCHIP_HLA_AA_SNP_1000G_fam=plink_KCHIP_HLA_AA_SNP_1000G.get_fam().astype({'fid':str,'iid':str}).rename(columns={'fid':'FID','iid':'IID'})
plink_KCHIP_HLA_AA_SNP_1000G_bim=plink_KCHIP_HLA_AA_SNP_1000G.get_bim()

# %%
phenotypes=pd.read_csv(pheno_all_file_path,sep='\t')
'  '.join(phenotypes.columns)
# Out:
# 'ID  age  sex  asthma  chronic_bronchitis  allergic_disease  stomach_cancer  liver_cancer  colorectal_cancer  breast_cancer  cervical_cancer  lung_cancer  thyroid_cancer  prostate_cancer  bladder_cancer  colon_polyps  angina_pectoris_myocardial_infarction  hypertension  stroke  transient_ischemic_attacks  acute_liver_disease  diabetes  hyperlipidemia  thyroid_disease  arthritis  rheumatoid_arthritis  osteoporosis  parkinson  pwi_total  chronic_gastritis_stomach_ulcer  duodenal_ulcer  urinary_tract_infection  height  hip_circumference  waist_circumference  weight  systolic_blood_pressure  diastolic_blood_pressure  pulse  hysterectomy  menarche_onset_age  menopause_age  menopause_cycle  ovarian_extraction  child_delivery_number  big_baby  small_baby  child_present  child_dead  hematocrit  hemoglobin  platelet  rbc  wbc  mcv  mch  mchc  total_bilirubin  bun  creatinine  blood_in_urine  glucose_in_urine  alt  ast  gtp  total_cholesterol  hdl_cholesterol  hba1c  freet4  tsh  triglyceride  albumin  hscrp  protein_in_urine  heart_failure  peripheral_vascular_diseases  cataract  glaucoma  renal_failure  renin  fatty_liver  copd  tuberculosis  benign_prostatic_hyperplasia  gout  fracture  cholelithiasis_cholecystitis  periodontal_disease  insomnia  sleep_duration  neurosis  grip_strength  FVC_predicted  FEV_predicted  FEV_over_FVC_predicted  MVV_predicted  bone_density_distal_sos  bone_density_midshaft_sos  protein_in_blood  glucose_in_blood  cohort  bmi'

# %%
phenotypes=phenotypes.set_index('ID').loc[plink_KCHIP_HLA_AA_SNP_1000G_fam['IID']]
phenotypes.shape
# Out:
# (125673, 101)

# %%
assert (phenotypes.index!=plink_KCHIP_HLA_AA_SNP_1000G_fam['IID']).sum()==0

# %%
#binary_continuous_traits=phenotypes.columns.difference(['age','sex','cohort'])
#binary_continuous_traits,len(binary_continuous_traits)

# %%
result_uni=pd.read_csv(data_out_gcta_path+'result_uni.tsv',sep='\t',index_col=0)

# %%
result_uni
# Out:
#                                        Intercept-Estimate  \
# FEV_over_FVC_predicted                          -0.000135
# FEV_predicted                                   -0.000134
# FVC_predicted                                   -0.000134
# MVV_predicted                                   -0.000134
# acute_liver_disease                             -0.000013
# albumin                                         -0.000008
# allergic_disease                                -0.000011
# alt                                             -0.000008
# angina_pectoris_myocardial_infarction           -0.000012
# arthritis                                       -0.000012
# ast                                             -0.000008
# asthma                                          -0.000012
# benign_prostatic_hyperplasia                    -0.000084
# big_baby                                        -0.000013
# bladder_cancer                                  -0.000013
# blood_in_urine                                  -0.000082
# bmi                                             -0.000008
# bone_density_distal_sos                         -0.000138
# bone_density_midshaft_sos                       -0.000138
# breast_cancer                                   -0.000019
# bun                                             -0.000008
# cataract                                        -0.000013
# cervical_cancer                                 -0.000019
# child_dead                                      -0.000254
# child_delivery_number                           -0.000014
# child_present                                   -0.000260
# cholelithiasis_cholecystitis                    -0.000013
# chronic_bronchitis                              -0.000013
# chronic_gastritis_stomach_ulcer                 -0.000011
# colon_polyps                                    -0.000012
# ...                                                   ...
# ovarian_extraction                              -0.000013
# parkinson                                       -0.000013
# periodontal_disease                             -0.000015
# platelet                                        -0.000012
# prostate_cancer                                 -0.000039
# protein_in_blood                                -0.000041
# protein_in_urine                                -0.000059
# pulse                                           -0.000008
# pwi_total                                       -0.000009
# rbc                                             -0.000011
# renal_failure                                   -0.000016
# renin                                           -0.000133
# rheumatoid_arthritis                            -0.000201
# sleep_duration                                  -0.000134
# small_baby                                      -0.000013
# stomach_cancer                                  -0.000012
# stroke                                          -0.000012
# systolic_blood_pressure                         -0.000008
# thyroid_cancer                                  -0.000012
# thyroid_disease                                 -0.000012
# total_bilirubin                                 -0.000013
# total_cholesterol                               -0.000008
# transient_ischemic_attacks                      -0.000013
# triglyceride                                    -0.000008
# tsh                                             -0.003501
# tuberculosis                                    -0.000084
# urinary_tract_infection                         -0.000012
# waist_circumference                             -0.000008
# wbc                                             -0.000012
# weight                                          -0.000008
#
#                                        Intercept-P_Jackknife  Intercept-P_OLS  \
# FEV_over_FVC_predicted                         2.873650e-271         0.478573
# FEV_predicted                                   0.000000e+00         0.479444
# FVC_predicted                                   0.000000e+00         0.479416
# MVV_predicted                                   0.000000e+00         0.479733
# acute_liver_disease                             3.071080e-39         0.479145
# albumin                                         0.000000e+00         0.480050
# allergic_disease                                0.000000e+00         0.479473
# alt                                             0.000000e+00         0.479865
# angina_pectoris_myocardial_infarction          4.147200e-190         0.479422
# arthritis                                       0.000000e+00         0.479483
# ast                                             0.000000e+00         0.480124
# asthma                                         1.391960e-126         0.479341
# bun                                              6.553160e-08
# cataract                                         3.890610e-07
# cervical_cancer                                  1.840850e-06
# child_dead                                       4.488660e-05
# child_delivery_number                            1.780710e-07
# child_present                                    1.265550e-05
# cholelithiasis_cholecystitis                     4.453160e-07
# chronic_bronchitis                               8.550530e-07
# chronic_gastritis_stomach_ulcer                  1.226790e-07
# colon_polyps                                     3.541830e-07
# ...                                                       ...
# ovarian_extraction                               3.582290e-07
# parkinson                                        4.656530e-06
# periodontal_disease                              3.276280e-07
# platelet                                         1.175230e-07
# prostate_cancer                                  1.011020e-05
# protein_in_blood                                 7.261040e-07
# protein_in_urine                                 3.449900e-06
# pulse                                            7.038740e-08
# pwi_total                                        8.483010e-08
# rbc                                              1.048460e-07
# renal_failure                                    2.968950e-06
# renin                                            6.539610e-06
# rheumatoid_arthritis                             1.818510e-05
# sleep_duration                                   4.422740e-06
# small_baby                                       4.664500e-07
# stomach_cancer                                   1.007270e-06
# stroke                                           5.571110e-07
# systolic_blood_pressure                          6.300860e-08
# thyroid_cancer                                   9.374970e-07
# thyroid_disease                                  3.070450e-07
# total_bilirubin                                  1.480850e-07
# total_cholesterol                                6.268600e-08
# transient_ischemic_attacks                       3.426210e-06
# triglyceride                                     9.045540e-08
# tsh                                              8.174830e-04
# tuberculosis                                     7.983820e-06
# urinary_tract_infection                          4.819810e-07
# waist_circumference                              5.906040e-08
# wbc                                              1.200930e-07
# weight                                           6.184070e-08
#
#                                        Intercept-SE_OLS  V(G)/Vp-Estimate  \
# FEV_over_FVC_predicted                         0.000190          0.002303
# FEV_predicted                                  0.000190         -0.000013
# FVC_predicted                                  0.000190          0.000071
# MVV_predicted                                  0.000190         -0.000780
# acute_liver_disease                            0.000019          0.000158
# albumin                                        0.000011          0.001063
# allergic_disease                               0.000016          0.000719
# alt                                            0.000012          0.000752
# angina_pectoris_myocardial_infarction          0.000017          0.000271
# arthritis                                      0.000016          0.000152
# ast                                            0.000012          0.001277
# asthma                                         0.000017          0.000439
# benign_prostatic_hyperplasia                   0.000118         -0.000407
# big_baby                                       0.000018          0.000020
# bladder_cancer                                 0.000018         -0.000100
# blood_in_urine                                 0.000115          0.003824
# bmi                                            0.000011          0.001084
# bone_density_distal_sos                        0.000195         -0.000072
# bone_density_midshaft_sos                      0.000195          0.002681
# breast_cancer                                  0.000027          0.000286
# bun                                            0.000011          0.000827
# cataract                                       0.000018          0.000121
# cervical_cancer                                0.000027          0.001199
# child_dead                                     0.000358         -0.002339
# child_delivery_number                          0.000020          0.000086
# child_present                                  0.000368         -0.001372
# cholelithiasis_cholecystitis                   0.000018         -0.000189
# chronic_bronchitis                             0.000019          0.000172
# chronic_gastritis_stomach_ulcer                0.000016          0.000207
# colon_polyps                                   0.000018          0.000163
# ...                                                 ...               ...
# ovarian_extraction                             0.000018          0.000063
# parkinson                                      0.000018         -0.000028
# periodontal_disease                            0.000021          0.000105
# platelet                                       0.000016          0.006042
# prostate_cancer                                0.000054          0.000296
# protein_in_blood                               0.000058          0.002268
# small_baby                                         0.000222        0.000123
# stomach_cancer                                     0.000241        0.000117
# stroke                                             0.000150        0.000115
# systolic_blood_pressure                            0.000166        0.000076
# thyroid_cancer                                     0.000163        0.000117
# thyroid_disease                                    0.000531        0.000114
# total_bilirubin                                    0.000321        0.000121
# total_cholesterol                                  0.000553        0.000075
# transient_ischemic_attacks                         0.000223        0.000123
# triglyceride                                       0.000620        0.000076
# tsh                                                0.043037        0.032142
# tuberculosis                                       0.001717        0.000795
# urinary_tract_infection                            0.000191        0.000116
# waist_circumference                                0.000216        0.000075
# wbc                                                0.000776        0.000109
# weight                                             0.000334        0.000075
#
#                                       phenotype_type  prevalence   h2_liab
# FEV_over_FVC_predicted                    continuous         NaN  0.002303
# FEV_predicted                             continuous         NaN -0.000013
# FVC_predicted                             continuous         NaN  0.000071
# MVV_predicted                             continuous         NaN -0.000780
# acute_liver_disease                           binary    0.005666  0.003419
# albumin                                   continuous         NaN  0.001063
# allergic_disease                              binary    0.073787  0.002513
# alt                                       continuous         NaN  0.000752
# angina_pectoris_myocardial_infarction         binary    0.024484  0.001964
# arthritis                                     binary    0.090298  0.000473
# ast                                       continuous         NaN  0.001277
# asthma                                        binary    0.016829  0.004158
# benign_prostatic_hyperplasia                  binary    0.008886 -0.006212
# big_baby                                      binary    0.042832  0.000100
# bladder_cancer                                binary    0.000398 -0.019319
# blood_in_urine                                binary    0.068493  0.013994
# bmi                                       continuous         NaN  0.001084
# bone_density_distal_sos                   continuous         NaN -0.000072
# bone_density_midshaft_sos                 continuous         NaN  0.002681
# breast_cancer                                 binary    0.007885  0.004778
# bun                                       continuous         NaN  0.000827
# cataract                                      binary    0.031508  0.000734
# cervical_cancer                               binary    0.005261  0.027403
# child_dead                                continuous         NaN -0.002339
# child_delivery_number                     continuous         NaN  0.000086
# child_present                             continuous         NaN -0.001372
# cholelithiasis_cholecystitis                  binary    0.025282 -0.001338
# chronic_bronchitis                            binary    0.007665  0.002932
# chronic_gastritis_stomach_ulcer               binary    0.131428  0.000520
# colon_polyps                                  binary    0.035616  0.000912
# ...                                              ...         ...       ...
# ovarian_extraction                            binary    0.036649  0.000345
# parkinson                                     binary    0.000271 -0.007557
# periodontal_disease                           binary    0.061487  0.000410
# platelet                                  continuous         NaN  0.006042
# prostate_cancer                               binary    0.001382  0.019925
# protein_in_blood                          continuous         NaN  0.002268
# protein_in_urine                              binary    0.036811  0.002477
# pulse                                     continuous         NaN  0.000153
# pwi_total                                 continuous         NaN  0.000031
# rbc                                       continuous         NaN  0.002211
# renal_failure                                 binary    0.001109 -0.004338
# renin                                     continuous         NaN -0.000936
# rheumatoid_arthritis                          binary    0.050085 -0.001598
# sleep_duration                            continuous         NaN  0.002634
# small_baby                                    binary    0.023546  0.001939
# stomach_cancer                                binary    0.004719  0.011954
# stroke                                        binary    0.014363  0.000131
# systolic_blood_pressure                   continuous         NaN  0.000471
# thyroid_cancer                                binary    0.005419  0.000139
# thyroid_disease                               binary    0.040892  0.013677
# total_bilirubin                           continuous         NaN  0.000766
# total_cholesterol                         continuous         NaN  0.003450
# transient_ischemic_attacks                    binary    0.000500 -0.018113
# triglyceride                              continuous         NaN  0.004474
# tsh                                       continuous         NaN -0.016886
# tuberculosis                                  binary    0.021315  0.025843
# urinary_tract_infection                       binary    0.018843 -0.000120
# waist_circumference                       continuous         NaN  0.000556
# wbc                                       continuous         NaN  0.006235
# weight                                    continuous         NaN  0.001400
#
# [96 rows x 13 columns]

# %%
grm_path='data/genotype/4_merge/KCHIP_HLA_AA_SNP_1000G.grm'

# %%
#np.all(pd.read_csv(data_out_gcta_path+phenotype_name1+'-'+phenotype_name2+'.phe',sep='\t',header=None)[2].isnull()|pd.read_csv(data_out_gcta_path+phenotype_name1+'-'+phenotype_name2+'.phe',sep='\t',header=None)[3].isnull())

# %%
rG_matrix_upper=np.zeros((len(result_uni),len(result_uni)))
rG_SE_matrix_upper=np.zeros((len(result_uni),len(result_uni)))

# %%
for i in range(0,len(result_uni)):
    for j in range(i+1,len(result_uni)):
        phenotype_name1=result_uni.iloc[i].name
        phenotype_name2=result_uni.iloc[j].name


        if os.path.exists(data_out_gcta_path+phenotype_name1+'-'+phenotype_name2+'.HEreg'):
            pass
        elif os.path.exists(data_out_gcta_path+phenotype_name2+'-'+phenotype_name1+'.HEreg'):
            (phenotype_name2,phenotype_name1)=phenotype_name1,phenotype_name2
        elif os.path.exists(data_out_gcta_path+phenotype_name2+'-'+phenotype_name1+'.log'):
            #print(phenotype_name1,phenotype_name2,'missing')
            with open(data_out_gcta_path+phenotype_name2+'-'+phenotype_name1+'.log') as f:
                if 'no phenotype data is found' in f.read():
                    continue
        elif os.path.exists(data_out_gcta_path+phenotype_name1+'-'+phenotype_name2+'.log'):
            #print(phenotype_name1,phenotype_name2,'missing')
            with open(data_out_gcta_path+phenotype_name1+'-'+phenotype_name2+'.log') as f:            
                if 'no phenotype data is found' in f.read():
                    continue            
        else:
            print(phenotype_name1,phenotype_name2)
            continue
            
        result1=pd.read_csv(data_out_gcta_path+'{}.HEreg'.format(phenotype_name1),skiprows=[0,1,2,3,4,5],sep=r'\s+').set_index('Coefficient')#,skiprows=[0,1],sep=r'\s*')
        result2=pd.read_csv(data_out_gcta_path+'{}.HEreg'.format(phenotype_name2),skiprows=[0,1,2,3,4,5],sep=r'\s+').set_index('Coefficient')#,skiprows=[0,1],sep=r'\s*')
        #pd.read_csv(data_out_gcta_path+phenotype_name1+'-'+phenotype_name2+'.phe',sep='\t',header=None)
        
        result_bivar=pd.read_csv(data_out_gcta_path+'{}-{}.HEreg'.format(phenotype_name1,phenotype_name2),skiprows=[0,1],sep=r'\s+').set_index('Coefficient')
        rG_matrix_upper[i][j]=result_bivar.loc['rG']['Estimate']
        rG_SE_matrix_upper[i][j]=result_bivar.loc['rG']['SE_OLS']
# Out:
# albumin urinary_tract_infection
# albumin waist_circumference
# albumin wbc
# albumin weight

# %%
def make_tri(mat):
    upper1=np.triu(mat,k=1)
    upper2=np.triu(mat.T,k=1) 
    
    ret=upper1+upper2 - np.where((upper1==upper2), upper1, 0)
    ret=np.triu(ret,k=1)
    return ret

# %%
#result_uni
phenotype_info=pd.read_csv('data/phenotype_info.tsv',sep='\t',index_col=0)

result_uni.index=phenotype_info.loc[result_uni.index]['phenotype_name_publication'].values

# %%
rG_matrix=make_tri(rG_matrix_upper)
rG_abs_matrix=np.abs(rG_matrix)
rG_SE_matrix=make_tri(rG_SE_matrix_upper)
rG_Z_abs_matrix=np.abs(rG_matrix/rG_SE_matrix)
# Out:
# /home/ch6845/tools/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# /home/ch6845/tools/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
rG_matrix_df=pd.DataFrame(rG_matrix,index=result_uni.index,columns=result_uni.index)
rG_abs_matrix_df=pd.DataFrame(rG_abs_matrix,index=result_uni.index,columns=result_uni.index)
#rG_Z_matrix_df=pd.DataFrame(rG_Z_matrix,index=result_uni.index,columns=result_uni.index)
rG_Z_abs_matrix_df=pd.DataFrame(rG_Z_abs_matrix,index=result_uni.index,columns=result_uni.index)
rG_SE_matrix_df=pd.DataFrame(rG_SE_matrix,index=result_uni.index,columns=result_uni.index)

# %%
#rGphenotype_info.loc[rG_matrix_df.index]['phenotype_name_publication'].values

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-fb4c0ffa998c> in <module>
#       1 phenotype_info=pd.read_csv('data/phenotype_info.tsv',sep='\t',index_col=0)
#       2
# ----> 3 phenotype_info.loc[toplot.index]
#
# NameError: name 'toplot' is not defined

# %%
edges=rG_matrix_df.mask(np.tril(np.ones(rG_matrix_df.shape)).astype(np.bool)).stack()
edges=pd.DataFrame([[edge[0][0],edge[0][1],edge[1]] for edge in edges.iteritems()],columns=['source','target','rG'])

# %%
edges2=rG_Z_abs_matrix_df.mask(np.tril(np.ones(rG_Z_abs_matrix_df.shape)).astype(np.bool)).stack()
edges2=pd.DataFrame([[edge[0][0],edge[0][1],edge[1]] for edge in edges2.iteritems()],columns=['source','target','Z_abs'])

# %%
edges3=rG_abs_matrix_df.mask(np.tril(np.ones(rG_abs_matrix_df.shape)).astype(np.bool)).stack()
edges3=pd.DataFrame([[edge[0][0],edge[0][1],edge[1]] for edge in edges3.iteritems()],columns=['source','target','rG_abs'])

# %%
edges=edges.merge(right=edges2,left_on=['source','target'],right_on=['source','target']).merge(right=edges3,left_on=['source','target'],right_on=['source','target'])

# %%
edges_filtered=edges.sort_values('Z_abs',ascending=False).iloc[:int(len(edges)*0.03)]#edges[edges['value']>2]

# %%
edges_filtered.shape
# Out:
# (79, 5)

# %%
#edges_filtered=edges_filtered.sort_values('rG_abs',ascending=True)#.iloc[:int(len(edges)*0.03)]#edges[edges['value']>2]
edges_filtered=edges_filtered[edges_filtered['rG_abs']>0.3]
edges_filtered.shape
# Out:
# (77, 5)

# %%
groups=[]
for idx,row in edges_filtered.iterrows():
    try:
        group_index=[(row['source'] in groups[i] or row['target'] in groups[i]) for i in range(len(groups))].index(True)
        groups[group_index].add(row['source'])
        groups[group_index].add(row['target'])
    except:
        groups.append({row['source'],row['target']})

# %%
groups=sorted(groups,key=lambda x: len(x),reverse=True)

# %%
len(groups)
# Out:
# 2

# %%
#phenotypes_par_filtered['group_id']=
edges_filtered['group_id']=[np.argmax([False]+[row['source'] in group for group in groups]) for idx,row in edges_filtered.iterrows()]

# %%
import networkx as nx

# %%
# 2557         Red blood cell count              Thyroid disease -0.468122
# 2008                   Hemoglobin                 Triglyceride  0.446448
# 1388                   Creatinine                 Hypertension  0.539365
# 1969                   Hematocrit            Total cholesterol  0.664369
# 1484     Diastolic blood pressure               Hyperlipidemia  0.958719
#
#           Z_abs    rG_abs  group_id
# 2646  39.096989  0.936455         1
# 1931  24.347781  0.908199         1
# 2472  23.303650  0.540922         1
# 2113  23.246528  0.971140         1
# 2111  23.047465  0.998808         1
# 1932  22.762630  0.738249         1
# 1417  19.960091  0.765220         1
# 1416  18.668803  0.757931         1
# 2478  18.350802  0.337919         1
# 2561  17.575281  0.673425         1
# 2633  17.187551  0.643098         1
# 2474  17.010242  0.337985         1
# 2317  16.613161  0.594909         1
# 2559  16.582219  0.655452         1
# 2150  16.327238  0.716400         1
# 2632  15.583784  0.605737         1
# 1900  15.416368  0.871495         1
# 1936  14.765876  0.849063         1
# 2302  14.607342  0.450822         1
# 2240  14.604047  0.940873         1
# 1420  14.389132  0.748832         1
# 1917  14.355819  0.521801         1
# 1902  14.271493  0.886695         1
# 963   14.089692  0.698419         1
# 2307  14.082867  0.808296         1
# 2315  13.597043  0.498522         1
# 2048  13.345787  0.914831         1
# 2470  12.792390  0.509022         1
# 2247  12.701042  0.539412         1
# 2148  12.695204  0.638033         1
# ...         ...       ...       ...
# 2099   9.985337  0.680973         1
# 2651   9.749064  0.353464         1
# 770    9.612067  0.637554         1
# 1834   9.316102  0.647143         1
# 2085   9.278993  0.744230         1
# 2260   9.146376  0.428344         1
# 2479   9.126266  0.386710         1
# 775    9.117127  0.614519         1
# 2664   9.104253  0.379275         1
# 2028   8.985007  0.321276         1
# 1907   8.912611  0.662502         1
# 1485   8.717914  1.094290         1
# 2007   8.596139  0.563948         1
# 2641   8.569302  0.710378         1
# 2313   8.423593  0.518302         1
# 185    8.254406  0.581527         1
# 1833   8.215146  0.581031         1
# 236    8.095673  0.712216         1
# 325    8.018036  0.716017         1
# 934    8.015322  0.653684         1
# 947    8.000851  0.617092         1
# 576    7.993849  0.305676         1
# 2639   7.985065  0.720264         1
# 386    7.885262  0.398999         1
# 547    7.879944  0.441648         1
# 2557   7.752854  0.468122         1
# 2008   7.739318  0.446448         1
# 1388   7.736092  0.539365         1
# 1969   7.699223  0.664369         1
# 1484   7.672637  0.958719         1
#
# [77 rows x 6 columns]

# %%
edges_filtered[edges_filtered['group_id']==2]
# Out:
# Empty DataFrame
# Columns: [source, target, rG, Z_abs, rG_abs, group_id]
# Index: []

# %%
edges_filtered_filtered=edges_filtered[edges_filtered['group_id']==1]
#edges_filtered_filtered=edges_filtered

G_temp=nx.convert_matrix.from_pandas_edgelist(edges_filtered_filtered,edge_attr=['rG','rG_abs','Z_abs'])

#per_bp_var_temp=per_bp_var.copy()
#per_bp_var_temp.index=per_bp_var_temp.index.map(lambda x:description_to_short(code_to_description(x),'pub',2))
nx.set_node_attributes(G_temp,dict([(node,pd.Series(result_uni['V(G)/Vp-Estimate'].loc[node]).iloc[0]) for node in list(G_temp.nodes)]),'heritability')
#nx.set_node_attributes(G_temp,dict([(node,node) for node in list(G.nodes)]),'label')

# %%
#G.edges['triglyceride', 'total_cholesterol']

# %%
#G=nx.relabel_nodes(G_temp,lambda x: description_to_short(code_to_description(x),'pub',2))

G=G_temp.copy()#nx.relabel_nodes(G_temp,lambda x:description_to_short(code_to_description(x),'abbr_pub_ori','correlation'))
pos = nx.kamada_kawai_layout(G,weight='Z_abs')

# %%
plt.rcParams["figure.figsize"] = (30,30)
plt.rcParams["font.size"] = 10
#sns.heatmap(rG_matrix_df, annot=True,cmap=plt.get_cmap('PiYG'),center=0,vmin=-1,vmax=1)

# %% [markdown]
# # Network

# %% [markdown]
# ## unique

# %% [markdown]
# # New

# %%
import random

angle_map=lambda x: (np.arctan(x[1]/x[0])+(np.pi if x[0]<0 else 0)+2*np.pi)%(2*np.pi)

def draw_arc(a,b):

    center=(a+b)/2+(1 if random.random()>0.5 else -1)*np.array([(b-a)[1],-(b-a)[0]])*random.uniform(np.sqrt(3)/2,2)

    radius=np.sqrt(np.power(b-center,2).sum())

    a_theta=angle_map(a-center)#arctan_norm((a-center)[1]/(a-center)[0])
    b_theta=angle_map(b-center)
    
    if abs(b_theta-a_theta)>np.pi:
        if a_theta>b_theta:
            a_theta=a_theta-2*np.pi
        else:
            b_theta=b_theta-2*np.pi
            
    try:
        return [center+radius*np.array([np.cos(theta),np.sin(theta)]) for theta in np.arange(min(a_theta,b_theta),max(a_theta,b_theta),abs(b_theta-a_theta)/100)]
    except:
        print('error')
        return [a,b]

#draw_arc(np.array((0,1)),np.array((1,0)))

# %%
#edge_df.sort_values('rG')

# %%
node_color='heritability'
node_size='heritability'

edge_width='Z_abs'
edge_color='rG'

from matplotlib.collections import LineCollection

plt.rcParams["figure.figsize"] = (15,20)
plt.rcParams["font.size"] = 30


#node initialization
node_df=pd.DataFrame([(pos[node]) for node in G.nodes],index=G.nodes,columns=['x','y'])
for node in G.nodes:
    for idx,value in G.nodes[node].items():
        node_df.loc[node,idx]=value

#edge initialization
edge_df=pd.DataFrame([(pos[edge[0]],pos[edge[1]]) for edge in G.edges],index=G.edges,columns=['source_xy','target_xy'])
for edge in G.edges:
    for idx,value in G.edges[edge].items():
        edge_df.loc[edge,idx]=value

############## Drawing ##############
        
# Draw colorbar
"""
scatter_x=node_df['x']
scatter_y=node_df['y']
scatter_hue=node_df[node_color]
points=plt.scatter(x=scatter_x,y=scatter_y,c=scatter_hue,cmap=plt.cm.PiYG)
        
plt.clf()
"""   

#,[
scatter_x=[i[0] for i in edge_df['source_xy'].values]
scatter_y=[i[1] for i in edge_df['source_xy'].values]
scatter_hue=edge_df[edge_color]
points=plt.scatter(x=scatter_x,y=scatter_y,c=scatter_hue,cmap=plt.cm.PiYG)
        
plt.clf()
  

fig, ax = plt.subplots()

plt.colorbar(points,orientation="horizontal",pad=0.07,shrink=0.3)   

# Draw edges


#line_collection_xy=[[row['source_xy'],(row['source_xy']+row['target_xy'])/2+(0.1,0.1),row['target_xy']] for idx,row in edge_df.iterrows()]
line_collection_xy=[draw_arc(row['source_xy'],row['target_xy']) for idx,row in edge_df.iterrows()]

line_collection_linewidths=np.array([row[edge_width] for idx,row in edge_df.iterrows()])
line_collection_linewidths=(line_collection_linewidths-line_collection_linewidths.min())/(line_collection_linewidths.max()-line_collection_linewidths.min())
line_collection_linewidths=2+3*line_collection_linewidths

line_collection_colors=np.array([plt.cm.PiYG(row[edge_color],alpha=0.7) for idx,row in edge_df.iterrows()])

line_collection=LineCollection(line_collection_xy,zorder=-5,colors=line_collection_colors,linewidths=line_collection_linewidths)
l_c=ax.add_collection(line_collection)

# Draw nodes

scatter_x=node_df['x']
scatter_y=node_df['y']
scatter_hue=node_df[node_color]
#scatter_hue=np.array([plt.cm.rainbow(row[node_color],alpha=0.7) for idx,row in node_df.iterrows()])
#
scatter_size=np.exp(node_df[node_size])
sns.scatterplot(x=scatter_x,y=scatter_y,hue=scatter_hue,palette=plt.cm.rainbow,vmin=-1,alpha=0.7,size=scatter_size,sizes=(100,1000),legend=None)#,color='white')#,edgecolor='black')


############## Annotation ##############


r_sample=np.arange(0.05,0.15,0.01)
theta_sample=2*np.pi*np.arange(0,1,0.05)
theta_sample=theta_sample[theta_sample%np.pi>np.pi/5]

np.random.shuffle(theta_sample)
move_sample=[(r*np.cos(theta),r*np.sin(theta)) for theta in theta_sample for r in r_sample]
#print(move_sample)
#print(move_sample)
text_plotted=pd.DataFrame([])
for idx,row in node_df.sort_values('y',ascending=False).iterrows():
    description_short=idx
    
    s=description_short
    xy=np.array([row['x'], row['y']])
    np.random.shuffle(theta_sample)
    move_sample=[(r*np.cos(theta),r*np.sin(theta)) for theta in theta_sample for r in r_sample]
    
    for move in move_sample:
        xytext=xy+move
        if text_plotted.shape[0]==0 or (((node_df['x']-xytext[0])**2+(node_df['y']-xytext[1])**2)<1).sum()==0 or (((text_plotted['x']-xytext[0])**2+0.5*(text_plotted['y']-xytext[1])**2)<0.05).sum()==0:
            plt.annotate(s,xy=xy,xytext=xytext,arrowprops=dict(arrowstyle="- >",connectionstyle="arc3,rad=0",ls='dashed'),bbox= dict(boxstyle="round,pad=0.3", fc=(1,1,1,0.5), ec="black", lw=0.3),size=15)
            text_plotted=text_plotted.append(pd.DataFrame([{'x':xytext[0],'y':xytext[1]}]))
            break

sns.despine(top=True,right=True,left=True,bottom=True)
plt.axis('off')

#plt.show()
plt.savefig('figure_network.svg', bbox_inches='tight')

# %%
node_color='per_bp_var'
node_size='per_bp_var'
edge_width='value'
edge_color='value'

from matplotlib.collections import LineCollection

plt.rcParams["figure.figsize"] = (20,25)
plt.rcParams["font.size"] = 15


#node initialization
node_df=pd.DataFrame([(pos[node]) for node in G.nodes],index=G.nodes,columns=['x','y'])
for node in G.nodes:
    for idx,value in G.nodes[node].items():
        node_df.loc[node,idx]=value

#edge initialization
edge_df=pd.DataFrame([(pos[edge[0]],pos[edge[1]]) for edge in G.edges],index=G.edges,columns=['source_xy','target_xy'])
for edge in G.edges:
    for idx,value in G.edges[edge].items():
        edge_df.loc[edge,idx]=value

############## Drawing ##############
        
# Draw colorbar
        
scatter_x=node_df['x']
scatter_y=node_df['y']
scatter_hue=node_df[node_color]
points=plt.scatter(x=scatter_x,y=scatter_y,c=scatter_hue,cmap=plt.cm.rainbow)
        
plt.clf()

fig, ax = plt.subplots()

plt.colorbar(points,orientation="horizontal",pad=0.07,shrink=0.3)   

# Draw edges


#line_collection_xy=[[row['source_xy'],(row['source_xy']+row['target_xy'])/2+(0.1,0.1),row['target_xy']] for idx,row in edge_df.iterrows()]
line_collection_xy=[draw_arc(row['source_xy'],row['target_xy']) for idx,row in edge_df.iterrows()]

line_collection_linewidths=np.array([row[edge_width] for idx,row in edge_df.iterrows()])
line_collection_linewidths=(line_collection_linewidths-line_collection_linewidths.min())/(line_collection_linewidths.max()-line_collection_linewidths.min())
line_collection_linewidths=1+5*line_collection_linewidths

line_collection_colors=np.array([plt.cm.Blues(row[edge_color],alpha=0.7) for idx,row in edge_df.iterrows()])

line_collection=LineCollection(line_collection_xy,zorder=-5,colors=line_collection_colors,linewidths=line_collection_linewidths)
l_c=ax.add_collection(line_collection)

# Draw nodes

scatter_x=node_df['x']
scatter_y=node_df['y']
scatter_hue=node_df[node_color]
#scatter_hue=np.array([plt.cm.rainbow(row[node_color],alpha=0.7) for idx,row in node_df.iterrows()])
#
scatter_size=np.exp(node_df[node_size])
sns.scatterplot(x=scatter_x,y=scatter_y,hue=scatter_hue,palette=plt.cm.rainbow,alpha=0.7,size=scatter_size,sizes=(100,1000),legend=None)#,color='white')#,edgecolor='black')


############## Annotation ##############


r_sample=np.arange(0.05,0.15,0.01)
theta_sample=2*np.pi*np.arange(0,1,0.05)
theta_sample=theta_sample[theta_sample%np.pi>np.pi/5]

np.random.shuffle(theta_sample)
move_sample=[(r*np.cos(theta),r*np.sin(theta)) for theta in theta_sample for r in r_sample]
#print(move_sample)
#print(move_sample)
text_plotted=pd.DataFrame([])
for idx,row in node_df.sort_values('y',ascending=False).iterrows():
    description_short=idx
    
    s=description_short
    xy=np.array([row['x'], row['y']])
    np.random.shuffle(theta_sample)
    move_sample=[(r*np.cos(theta),r*np.sin(theta)) for theta in theta_sample for r in r_sample]
    
    move=move_sample[0]
    xytext=xy+move
    #plt.annotate(s,xy=xy,xytext=xytext,arrowprops=dict(arrowstyle="- >",connectionstyle="arc3,rad=0",ls='dashed'),bbox= dict(boxstyle="round,pad=0.3", fc=(1,1,1,0.5), ec="black", lw=0.3),size=15)
    

sns.despine(top=True,right=True,left=True,bottom=True)
plt.axis('off')
plt.savefig('network.svg')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/tools/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'per_bp_var'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-9140a6f5f4ba> in <module>
#      28 scatter_x=node_df['x']
#      29 scatter_y=node_df['y']
# ---> 30 scatter_hue=node_df[node_color]
#      31 points=plt.scatter(x=scatter_x,y=scatter_y,c=scatter_hue,cmap=plt.cm.rainbow)
#      32
#
# ~/tools/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/tools/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'per_bp_var'

# %%
node_color='per_bp_var'
node_size='per_bp_var'
edge_width='value'
edge_color='value'

from matplotlib.collections import LineCollection

plt.rcParams["figure.figsize"] = (20,25)
plt.rcParams["font.size"] = 15


#node initialization
node_df=pd.DataFrame([(pos[node]) for node in G.nodes],index=G.nodes,columns=['x','y'])
for node in G.nodes:
    for idx,value in G.nodes[node].items():
        node_df.loc[node,idx]=value

#edge initialization
edge_df=pd.DataFrame([(pos[edge[0]],pos[edge[1]]) for edge in G.edges],index=G.edges,columns=['source_xy','target_xy'])
for edge in G.edges:
    for idx,value in G.edges[edge].items():
        edge_df.loc[edge,idx]=value

############## Drawing ##############
        
# Draw colorbar
        
scatter_x=node_df['x']
scatter_y=node_df['y']
scatter_hue=node_df[node_color]
points=plt.scatter(x=scatter_x,y=scatter_y,c=scatter_hue,cmap=plt.cm.rainbow)
        
plt.clf()

fig, ax = plt.subplots()

plt.colorbar(points,orientation="horizontal",pad=0.07,shrink=0.3)   

# Draw edges


#line_collection_xy=[[row['source_xy'],(row['source_xy']+row['target_xy'])/2+(0.1,0.1),row['target_xy']] for idx,row in edge_df.iterrows()]
line_collection_xy=[draw_arc(row['source_xy'],row['target_xy']) for idx,row in edge_df.iterrows()]

line_collection_linewidths=np.array([row[edge_width] for idx,row in edge_df.iterrows()])
line_collection_linewidths=(line_collection_linewidths-line_collection_linewidths.min())/(line_collection_linewidths.max()-line_collection_linewidths.min())
line_collection_linewidths=1+5*line_collection_linewidths

line_collection_colors=np.array([plt.cm.hsv(row[edge_color],alpha=0.7) for idx,row in edge_df.iterrows()])

line_collection=LineCollection(line_collection_xy,zorder=-5,colors=line_collection_colors,linewidths=line_collection_linewidths)
l_c=ax.add_collection(line_collection)

# Draw nodes

scatter_x=node_df['x']
scatter_y=node_df['y']
scatter_hue=node_df[node_color]
#scatter_hue=np.array([plt.cm.rainbow(row[node_color],alpha=0.7) for idx,row in node_df.iterrows()])
#
scatter_size=np.exp(node_df[node_size])
sns.scatterplot(x=scatter_x,y=scatter_y,hue=scatter_hue,palette=plt.cm.Blues,alpha=0.7,size=scatter_size,sizes=(100,1000),legend=None)#,color='white')#,edgecolor='black')


############## Annotation ##############


r_sample=np.arange(0.05,0.15,0.01)
theta_sample=2*np.pi*np.arange(0,1,0.05)
theta_sample=theta_sample[theta_sample%np.pi>np.pi/5]

np.random.shuffle(theta_sample)
move_sample=[(r*np.cos(theta),r*np.sin(theta)) for theta in theta_sample for r in r_sample]
#print(move_sample)
#print(move_sample)
text_plotted=pd.DataFrame([])
for idx,row in node_df.sort_values('y',ascending=False).iterrows():
    description_short=idx
    
    s=description_short
    xy=np.array([row['x'], row['y']])
    np.random.shuffle(theta_sample)
    move_sample=[(r*np.cos(theta),r*np.sin(theta)) for theta in theta_sample for r in r_sample]
    
    for move in move_sample:
        xytext=xy+move
        if text_plotted.shape[0]==0 or (((node_df['x']-xytext[0])**2+(node_df['y']-xytext[1])**2)<1).sum()==0 or (((text_plotted['x']-xytext[0])**2+0.5*(text_plotted['y']-xytext[1])**2)<0.05).sum()==0:
            plt.annotate(s,xy=xy,xytext=xytext,arrowprops=dict(arrowstyle="- >",connectionstyle="arc3,rad=0",ls='dashed'),bbox= dict(boxstyle="round,pad=0.3", fc=(1,1,1,0.5), ec="black", lw=0.3),size=15)
            text_plotted=text_plotted.append(pd.DataFrame([{'x':xytext[0],'y':xytext[1]}]))
            break

sns.despine(top=True,right=True,left=True,bottom=True)
plt.axis('off')

plt.show()
# Out:
# /home/ch6845/tools/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
# error
# error
# error

# %%
line_collection_linewidths=np.array([row[edge_width] for idx,row in edge_df.iterrows()])
line_collection_linewidths=(line_collection_linewidths-line_collection_linewidths.min())/(line_collection_linewidths.max()-line_collection_linewidths.min())
line_collection_linewidths=1+5*line_collection_linewidths
